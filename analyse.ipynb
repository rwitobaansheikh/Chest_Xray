# %%
import os
current_directory = os.getcwd()
print(current_directory)
import pandas as pd
database = pd.read_csv("Data_Entry_2017.csv")
Filterdata = database[database['Finding Labels']!= 'No Finding']
sign ="|"
singlelabeldata = Filterdata[Filterdata['Finding Labels'].str.contains('\|')==False]
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# <>:8: SyntaxWarning: invalid escape sequence '\|'
# C:\Users\Fiona Lee\AppData\Local\Temp\ipykernel_25208\487337521.py:8: SyntaxWarning: invalid escape sequence '\|'
#   singlelabeldata = Filterdata[Filterdata['Finding Labels'].str.contains('\|')==False]
# d:\archive

# %%
singlelabeldata["Finding Labels"].value_counts()
# Out:
# Finding Labels
# Infiltration          9547
# Atelectasis           4215
# Effusion              3955
# Nodule                2705
# Pneumothorax          2194
# Mass                  2139
# Consolidation         1310
# Pleural_Thickening    1126
# Cardiomegaly          1093
# Emphysema              892
# Fibrosis               727
# Edema                  628
# Pneumonia              322
# Hernia                 110
# Name: count, dtype: int64

# %%
Filterdata["Finding Labels"].value_counts()
# Out:
# Finding Labels
# Infiltration                                                       9547
# Atelectasis                                                        4215
# Effusion                                                           3955
# Nodule                                                             2705
# Pneumothorax                                                       2194
#                                                                    ...
# Atelectasis|Consolidation|Edema|Effusion|Infiltration|Pneumonia       1
# Atelectasis|Consolidation|Effusion|Emphysema|Mass|Pneumothorax        1
# Cardiomegaly|Effusion|Pleural_Thickening|Pneumothorax                 1
# Edema|Infiltration|Pneumothorax                                       1
# Atelectasis|Consolidation|Mass|Pleural_Thickening|Pneumothorax        1
# Name: count, Length: 835, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = singlelabeldata.drop('Finding Labels',axis =1)
y = singlelabeldata["Finding Labels"]
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size=0.1, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=1)

# %%
X_train
# Out:
#              Image Index  Follow-up #  Patient ID  Patient Age Patient Gender  \
# 24268   00006381_018.png           18        6381           30              F
# 35948   00009485_002.png            2        9485           60              M
# 98783   00026113_000.png            0       26113           70              M
# 105947  00028518_016.png           16       28518           48              F
# 77057   00018921_073.png           73       18921           43              F
# ...                  ...          ...         ...          ...            ...
# 6575    00001765_000.png            0        1765           67              F
# 80224   00019718_001.png            1       19718           52              M
# 38771   00010120_027.png           27       10120           53              M
# 50392   00012758_000.png            0       12758            9              M
# 100634  00026713_013.png           13       26713           62              F
#
# ...

# %%
image_name = X_train.iloc[0]["Image Index"]
image_name
# Out:
# '00006381_018.png'

# %%
image_name = X_train.iloc[0]["Image Index"]

import os
import matplotlib.pyplot as plt 
import matplotlib.image as img 
current_directory = os.getcwd()

subfolders = [ f.path for f in os.scandir(current_directory) if f.is_dir() ]


for foldername in subfolders:
   
    for file in os.listdir(foldername+'\\images'):
        file_dir = os.path.join(foldername+'\\images',file)
        #print(file)
        if file == image_name:
            print(file_dir)
            # reading png image file 
            im = img.imread(file_dir) 
  
            # show image 
            plt.imshow(im)
# Out:
# d:\archive\images_003\images\00006381_018.png
